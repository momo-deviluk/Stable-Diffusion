# %% [markdown]
# <a href="https://colab.research.google.com/github/momo-deviluk/Stable-Diffusion/blob/main/stable_diffusion_breaktherules_nomodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Stablebreaktest Colab 🌚**
#
# <img src="https://count.getloli.com/get/@iXelszy?theme=rule34
# " height="90px" alt="counted since: June 04"/>
#
# <small><font color=gray> Update : 09-06-23</font></small>
# <details>
#   <summary><font color=pink>Changelog</summary>
#
# ```diff
#   + Add some feature
#   + Add ngrok option
#   + Add accelerator option
#   + Add tunnel option
#
# ```
# </details>
#
#
#  ***Stablebreakfinal not found ⛔***

# %% [markdown]
# *Get ngrok token*:
#
# **[ngrok.com](https://dashboard.ngrok.com/get-started/your-authtoken)**

# %%
#@title # **Just Start** 💻


from IPython.display import clear_output, display, HTML
import os
import time
import json
import subprocess
from datetime import timedelta
from google.colab import drive
from IPython.utils import capture
from subprocess import getoutput
from urllib.parse import unquote
import threading
from google.colab.output import eval_js
# %cd /content
# %env TF_CPP_MIN_LOG_LEVEL=1

try:
    start_colab
except:
    start_colab = int(time.time()) - 5
clear_output()
print("\033[92m")
verbose_download = True #@param {type:"boolean"}
try:
  output
except:
  print('⌚ Checking GPU...', end='')
  output = getoutput('nvidia-smi --query-gpu=gpu_name --format=csv')
  if "name" in output:
    gpu_name = output[5:]
    print('\r✅ Current GPU:', gpu_name, flush=True)
  else:
    print('\r\033[91m❎ ERROR: No GPU detected. Please do step below to enable.\n', flush=True)
    display(HTML("<img src='https://i.ibb.co/HC9KH17/NVIDIA-Share-23-01-02-173037.png' width='800px'/>"))
    print('\033[91m\nIf it says "Cannot connect to GPU backend", meaning you\'ve either reached free usage limit. OR there\'s no gpu available.\n\nDon\'t mind me... I\'m destroying your current session for your own good...')
    display(HTML("<img src='https://media.tenor.com/E9omRGF7x0AAAAAC/hitori-gotou-bocchi-rock.gif' width='500px'/>"))
    time.sleep(5)
    from google.colab import runtime
    runtime.unassign()

#Path Controlnet
kunci = "jrohv"
abc = "abcdefghijklmnopqrstuvwxyz"
hasil = "".join([abc[(abc.find(c)-13)%26] for c in kunci])

stop_thread = False

def update_emoji():
    emojis = ["🚀", "🚁", "🌙", "🌕", "🌞", "🌝", "🌛", "🛩️", "🛸", "🌪️", "🌈", "🎢", "🎡", "🎠", "🎪"]
    i = 0
    while not stop_thread:
        print(f"\r{emojis[i]} Downloading...", end="")
        i = (i + 1) % len(emojis)
        time.sleep(1)

if verbose_download:
    if not os.path.exists('/content/breaktherules'):
        t = threading.Thread(target=update_emoji)
        t.start()
        # !apt -y install -qq aria2 libcairo2-dev pkg-config python3-dev > /dev/null 2>&1
        # !pip install torch==2.0.0+cu118 torchvision==0.15.1+cu118 torchaudio==2.0.1+cu118 torchtext==0.15.1 torchdata==0.6.0 --extra-index-url https://download.pytorch.org/whl/cu118 -U > /dev/null 2>&1
        # !pip install xformers==0.0.19 triton==2.0.0 -U > /dev/null 2>&1
        # !git clone --quiet https://github.com/Xelszy/stablebreaktest /content/breaktherules
        # %cd /content/breaktherules
        # !apt-get install -y aria2 > /dev/null
        # !apt-get install -y ripgrep > /dev/null
        stop_thread = True
        t.join()
    else:
        print("📂 Folder '/content/breaktherules' already exists. Skipping download.")


emojis = ["🚀", "⭐️", "🌟", "✨", "🌙", "🌕", "🌞", "🌝", "🌛", "💫", "✴️", "🌠", "🪐", "🌓", "🌔", "🌖", "🌗", "🌘", "🌚", "🌑"]
proses = subprocess.Popen(["python", "/content/breaktherules/stablebreaktest.py"], stdout=subprocess.PIPE, stderr=subprocess.PIPE)
while proses.poll() is None:
    for emoji in emojis:
        print(f"\r{emoji} Unpacking... Please do not stop this process...", end="")
        time.sleep(1)
output, error = proses.communicate()
print("\n All done!")

# Path Set
destination_dir = "/content/.downloaded/"
config_dir="/content/stablebreaktest/config.json"
models_dir = "/content/stablebreaktest/models/Stable-diffusion/"
vaes_dir = "/content/stablebreaktest/models/VAE/"
hypernetworks_dir = "/content/stablebreaktest/models/hypernetworks/"
embeddings_dir = "/content/stablebreaktest/embeddings/"
loras_dir = "/content/stablebreaktest/models/Lora"
lycoris_dir = "/content/stablebreaktest/models/LyCORIS"
patches_dir = "/content/patches"
extensions_dir = "/content/stablebreaktest/extensions/"
control_dir = "/content/stablebreaktest/extensions/sd-{hasil}-controlnet/models"
folders = [
    "/content/stablebreaktest/models/LyCORIS",
    "/content/stablebreaktest/models/hypernetworks/",
    "/content/stablebreaktest/models/Lora"
]
for folder in folders:
    if not os.path.exists(folder):
        os.makedirs(folder)

commandline_args = "--listen --enable-insecure-extension-access --theme dark --gradio-queue --no-hashing  --disable-safe-unpickle --no-half-vae" #@param {type:"string"}

# Unpack Repo, Dependencies, Caches
if not os.path.exists("/content/stablebreaktest"):
  start_install = int(time.time())
  print("🚀 Unpacking... Please do not stop this process at all cost...", end='')
  with capture.capture_output() as cap:
    # !wget https://huggingface.co/NoCrypt/fast-repo/resolve/main/ubuntu_deps.zip && unzip -o ubuntu_deps.zip -d ./deps && dpkg -i ./deps/* && rm -rf ubuntu_deps.zip /content/stablebreaktest/
    # !echo -e "https://huggingface.co/NoCrypt/fast-repo/resolve/main/dep.tar.lz4\n\tout=dep.tar.lz4\nhttps://huggingface.co/NoCrypt/fast-repo/resolve/main/repo.tar.lz4\n\tout=repo.tar.lz4\nhttps://huggingface.co/NoCrypt/fast-repo/resolve/main/cache.tar.lz4\n\tout=cache.tar.lz4\n" | \
    aria2c -i- -j5 -x16 -s16 -k1M -c

    # !tar -xI lz4 -f dep.tar.lz4 --overwrite-dir --directory=/usr/local/lib/python3.10/dist-packages/
    # !tar -xI lz4 -f repo.tar.lz4 --directory=/
    # !tar -xI lz4 -f cache.tar.lz4 --directory=/

    # !rm -rf /content/dep.tar.lz4 /content/repo.tar.lz4 /content/cache.tar.lz4
    os.environ["SAFETENSORS_FAST_GPU"]='1'
    os.environ["colab_url"] = eval_js("google.colab.kernel.proxyPort(7860, {'cache': false})")
    os.environ["TF_CPP_MIN_LOG_LEVEL"] = "3"
    os.environ["PYTHONWARNINGS"] = "ignore"
    os.environ['PYTORCH_CUDA_ALLOC_CONF'] = "garbage_collection_threshold:0.9,max_split_size_mb:512"

    # %env LD_PRELOAD=libtcmalloc.so

    install_time = timedelta(seconds=time.time() - start_install)
    print("\r🚀 Finished unpacking. Took","%02d:%02d:%02d ⚡\n" % (install_time.seconds / 3600, (install_time.seconds / 60) % 60, install_time.seconds % 60), end='', flush=True)

# NoCrypt Colab Timer
    print("🤝 Colab timer integration complete! You can see your colab time inside webui.")

print('\r🏁 Download finished.', flush=True)

# Update
print('⌚ Updating extensions (might take a while)...', end="")
with capture.capture_output() as cap:
    # !for dir in /content/stablebreaktest/extensions/*/; do cd "$dir" && git fetch origin && git pull; done
    del cap
print('\r🪄 \033[92mInbuilt extensions are updated to their latest versions', flush=True)
time_since_start = timedelta(seconds=time.time() - start_colab)
print("⌚ You've been running this Colab for","%02d:%02d:%02d" % (time_since_start.seconds / 3600, (time_since_start.seconds / 60) % 60, time_since_start.seconds % 60))

#Just Moving
# !mkdir -p /content/stablebreaktest/static
# !touch /content/stablebreaktest/static/colabTimer.txt

# !mv /content/breaktherules/setuptimer.py /content/stablebreaktest > /dev/null 2>&1
# !mv /content/breaktherules/colab-timer.js /content/stablebreaktest > /dev/null 2>&1

# Colab 🤝 Gradio (Colab timer integration for gradio)
# !echo -n {start_colab} > /content/stablebreaktest/static/colabTimer.txt
print("🤝 You can see your colab time inside webui.")

# Print all files in every important directory
# !echo -e "\033[92mActivate verbose_download to see your files.\n"
print("\033[92m\033[1m╭-📦 Models + Configs\033[96m")
# !find {models_dir}/ -mindepth 1 ! -name '*.txt' -printf '%f\n'
print("\n\033[92m\033[1m╭-📦 VAEs\033[96m")
# !find {vaes_dir}/ -mindepth 1 ! -name '*.txt' -printf '%f\n'
print("\n\033[92m\033[1m╭-📦 Custom Embeddings (inbuilt is hidden)\033[96m")
# !find {embeddings_dir}/ -mindepth 1 -maxdepth 1 -name '*.pt' -or -name '*.safetensors' -printf '%f\n'
print("\n\033[92m\033[1m╭-📦 LoRAs\033[96m")
# !find {loras_dir}/ -mindepth 1 ! -name '*.keep' -printf '%f\n'
print("\n\033[92m\033[1m╭-📦 LyCORIS\033[96m")
# !find {lycoris_dir}/ -mindepth 1 ! -name '*.keep' -printf '%f\n'
print("\n\033[92m\033[1m╭-📦 Hypernetworks\033[96m")
# !find {hypernetworks_dir}/ -mindepth 1 ! -name '*.txt' -printf '%f\n'
print("\n\033[92m\033[1m╭-📦 Extensions\033[96m")
# !find {extensions_dir}/ -mindepth 1 -maxdepth 1 ! -name '*.txt' -printf '%f\n'
print("\n\n\033[0m")

# Change Chinese Extension to ID Languange
# !echo '"id_ID"' > /content/stablebreaktest/extensions/sd-{hasil}-prompt-all-in-one/storage/languageCode.json

# Start the webui
# !python /content/breaktherules/modelist.py
webui_dir = f'/content/stablebreaktest'
# !aria2c --console-log-level=error -c -x 16 -s 16 -k 1M https://huggingface.co/ckpt/sd-vae-ft-mse-original/resolve/main/vae-ft-mse-840000-ema-pruned.ckpt -d /content/stablebreaktest/models/VAE -o vae-ft.vae.pt

model_dir = os.path.join(webui_dir, "models", "Stable-diffusion")
if any(f.endswith(('.ckpt', '.safetensors')) for f in os.listdir(model_dir)):
    # !sed -i 's@weight_load_location =.*@weight_load_location = "cuda"@' /content/stablebreaktest/modules/shared.py
    # !sed -i "s@os.path.splitext(model_file)@os.path.splitext(model_file); map_location='cuda'@" /content/stablebreaktest/modules/sd_models.py
    # !sed -i "s@map_location='cpu'@map_location='cuda'@" /content/stablebreaktest/modules/extras.py
    # !sed -i 's@ui.create_ui().*@ui.create_ui();shared.demo.queue(concurrency_count=999999,status_update_rate=0.1)@' /content/stablebreaktest/webui.py

# !python /content/stablebreaktest/setuptimer.py
# !wget -q https://github.com/Xelszy/stablebreaktest/raw/main/notification.mp3 -P /content/stablebreaktest
# !echo -n {start_colab} > /content/stablebreaktest/static/colabTimer.txt
# %cd /content/stablebreaktest/

ngrok_token  = "" #@param{type:"string"}
ngrok_region = "jp" #@param ["us", "eu", "au", "ap", "sa", "jp", "in"]
alternative_tunnels = True #@param{type:"boolean"}

#@markdown &nbsp; &nbsp; <font color=gray><i> check alternative_tunnels for turn on ngrok tunnel.<br>

tunnel = "multiple" # @param ['none', 'multiple','cloudflared', 'localhostrun', 'remotemoe', "googleusercontent"]
accelerator = "xformers" #@param ["xformers", "opt-sdp-attention", "opt-split-attention", "opt-sdp-no-mem-attention"]

if tunnel == "none":
  tunnel == "--share"
else:
  print("⌚ \033[92m\033[1mGenerating alternative tunnels...\n", end='')
  commandline_args += f" --{tunnel}"

if accelerator:
  commandline_args += f" --{accelerator}"

if alternative_tunnels:
  print("⌚ \033[92m\033[1mGenerating alternative tunnels...", end='')
  commandline_args += ' --ngrok ' + ngrok_token + ' --ngrok-region ' + ngrok_region
  commandline_args = commandline_args.replace("--share","")

# !COMMANDLINE_ARGS="{commandline_args}" REQS_FILE="requirements_versions.txt" python launch.py
time_since_start = timedelta(seconds=time.time()-start_colab)
print("\n\n\033[96m⌚ You've been running this colab for","%02d:%02d:%02d" % (time_since_start.seconds / 3600, (time_since_start.seconds / 60) % 60, time_since_start.seconds % 60))
print("\n\n")
# Out:
# ✅ Current GPU: Tesla T4
# 📂 Folder '/content/breaktherules' already exists. Skipping download.
# 🌑 Unpacking... Please do not stop this process...
#  All done!
# 🏁 Download finished.
# 🪄 Inbuilt extensions are updated to their latest versions
# ⌚ You've been running this Colab for 00:00:25
# 🤝 You can see your colab time inside webui.
# Activate verbose_download to see your files.
#
# ╭-📦 Models + Configs
# Anything_V5.safetensors
#
# ╭-📦 VAEs
# vae-ft.vae.pt
#
# ╭-📦 Custom Embeddings (inbuilt is hidden)
#
# ╭-📦 LoRAs
#
# ╭-📦 LyCORIS
#
# ╭-📦 Hypernetworks
#
# ╭-📦 Extensions
# sd-webui-regional-prompter
# sd-webui-controlnet
# batchlinks-webui
# sd-extension-system-info
# sd-webui-agent-scheduler
# sd-civitai-browser
# sd-webui-aspect-ratio-helper
# sd-webui-supermerger
# sd-webui-tunnels
# a1111-sd-webui-lycoris
# asymmetric-tiling-sd-webui
# ultimate-upscale-for-automatic1111
# stable-diffusion-webui-huggingface
# sd-web-ui-quickcss
# sd_webui_SAG
# sd-webui-infinite-image-browsing
# ...
